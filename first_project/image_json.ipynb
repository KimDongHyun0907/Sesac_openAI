# %%
from glob import glob

file_paths = glob('C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_인사이드/*')

b = []
for data in file_paths:
    a = data.split('\\')
    b.append(a[1][:a[1].find('_a')])

b1 = list(set(b))
b1
# Out:
# ['a64mr1_006_3aa_1800021.550_20220920_0036',
#  'a73mr1_107_3bb_1600026.755_20220915_0227',
#  'a02ml1_020_3bb_2180022.935_20220921_0020',
#  'a17mr1_097_3aa_2770025.568_20220913_0217',
#  'a01mr1_007_3aa_1860025.253_20220929_0667',
#  'a02ml1_148_3bb_1500027.250_20220902_0308',
#  'a01mr1_154_3bb_0820126.950_20220902_0274',
#  'a23mr1_021_3bb_2200023.734_20220921_0351',
#  'a51mr1_144_3bb_1420029.663_20220916_0764',
#  'a56mr1_141_3bb_3280028.257_20220912_0381',
#  'a21mr1_019_3bb_2180022.935_20220921_0079',
#  'a02ml1_154_3bb_1500027.250_20220902_0314',
#  'a24mr1_027_3bb_1450025.650_20220929_0657',
#  'a73mr1_112_3bb_1600026.755_20220915_0232',
#  'a02ml1_130_3aa_1550026.849_20220902_0290',
#  'a13mr1_160_3bb_1420029.663_20220916_0780',
#  'a01mr1_157_3bb_1730026.365_20220913_0877',
#  'a54mr1_039_3bb_2170023.241_20220920_0679',
#  'a11mr1_158_3bb_2770126.465_20220913_0918',
#  'a64mr1_012_3aa_1800021.550_20220920_0042',
#  'a11mr1_155_3bb_2770126.465_20220913_0915',
# ...

# %%
from glob import glob

file_paths2 = glob('C:/Users/bluecom014/Downloads/299.비전영역, 축구 킥 동작 및 축구공 궤적 데이터 구축/01-1.정식개방데이터/Training/02.라벨링데이터/TL_2.trajectory_후기-궤적/*')

c = []
for data in file_paths2:
    a = data.split('\\')
    c.append(a[1][:a[1].find('_b')])

# %%
d = [i for i in b1 if i in c]

d
# Out:
# ['a02ml1_148_3bb_1500027.250_20220902_0308',
#  'a01mr1_154_3bb_0820126.950_20220902_0274',
#  'a02ml1_154_3bb_1500027.250_20220902_0314',
#  'a24mr1_027_3bb_1450025.650_20220929_0657',
#  'a04mr1_028_3bb_1710018.384_20220929_0058',
#  'a02ml1_153_3bb_1500027.250_20220902_0313',
#  'a02ml1_159_3bb_1500027.250_20220902_0319',
#  'a01mr1_131_3aa_1620326.849_20220902_0251',
#  'a04mr1_024_3bb_1710018.384_20220929_0054',
#  'a02ml1_149_3bb_1500027.250_20220902_0309',
#  'a02ml1_156_3bb_1500027.250_20220902_0316',
#  'a01mr1_142_3bb_0820126.950_20220902_0262',
#  'a01mr1_124_3aa_1620326.849_20220902_0244',
#  'a01mr1_155_3bb_0820126.950_20220902_0275',
#  'a02ml1_145_3bb_1500027.250_20220902_0305',
#  'a02ml1_146_3bb_1500027.250_20220902_0306',
#  'a02ml1_022_3bb_1660018.385_20220929_0022',
#  'a01mr1_149_3bb_0820126.950_20220902_0269',
#  'a02ml1_152_3bb_1500027.250_20220902_0312',
#  'a01mr1_001_3aa_1860025.253_20220929_0661',
#  'a04mr1_019_3bb_1710018.384_20220929_0049',
# ...

# %%
selected_files = ['C:/Users/bluecom014/Downloads/299.비전영역, 축구 킥 동작 및 축구공 궤적 데이터 구축/01-1.정식개방데이터/Training/02.라벨링데이터/TL_2.trajectory_후기-궤적/'+i+'_b.json' for i in b1 if i in c]

selected_files
# Out:
# ['C:/Users/bluecom014/Downloads/299.비전영역, 축구 킥 동작 및 축구공 궤적 데이터 구축/01-1.정식개방데이터/Training/02.라벨링데이터/TL_2.trajectory_후기-궤적/a02ml1_148_3bb_1500027.250_20220902_0308_b.json',
#  'C:/Users/bluecom014/Downloads/299.비전영역, 축구 킥 동작 및 축구공 궤적 데이터 구축/01-1.정식개방데이터/Training/02.라벨링데이터/TL_2.trajectory_후기-궤적/a01mr1_154_3bb_0820126.950_20220902_0274_b.json',
#  'C:/Users/bluecom014/Downloads/299.비전영역, 축구 킥 동작 및 축구공 궤적 데이터 구축/01-1.정식개방데이터/Training/02.라벨링데이터/TL_2.trajectory_후기-궤적/a02ml1_154_3bb_1500027.250_20220902_0314_b.json',
#  'C:/Users/bluecom014/Downloads/299.비전영역, 축구 킥 동작 및 축구공 궤적 데이터 구축/01-1.정식개방데이터/Training/02.라벨링데이터/TL_2.trajectory_후기-궤적/a24mr1_027_3bb_1450025.650_20220929_0657_b.json',
#  'C:/Users/bluecom014/Downloads/299.비전영역, 축구 킥 동작 및 축구공 궤적 데이터 구축/01-1.정식개방데이터/Training/02.라벨링데이터/TL_2.trajectory_후기-궤적/a04mr1_028_3bb_1710018.384_20220929_0058_b.json',
# ...

# %%
import shutil

for file in selected_files:
    shutil.copyfile(file, 'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/인사이드_json/'+file.split('/')[-1])

# %%
e = [data for data in file_paths if data.split('\\')[1][:data.split('\\')[1].find('_a')] in d]
e
# Out:
# ['C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_인사이드\\a01mr1_001_3aa_1860025.253_20220929_0661_a-01_frame761.jpg',
#  'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_인사이드\\a01mr1_001_3aa_1860025.253_20220929_0661_a-02_frame761.jpg',
#  'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_인사이드\\a01mr1_001_3aa_1860025.253_20220929_0661_a-03_frame761.jpg',
#  'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_인사이드\\a01mr1_001_3aa_1860025.253_20220929_0661_a-04_frame761.jpg',
#  'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_인사이드\\a01mr1_001_3aa_1860025.253_20220929_0661_a-05_frame761.jpg',
#  'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_인사이드\\a01mr1_001_3aa_1860025.253_20220929_0661_a-06_frame761.jpg',
#  'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_인사이드\\a01mr1_001_3aa_1860025.253_20220929_0661_a-07_frame761.jpg',
#  'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_인사이드\\a01mr1_001_3aa_1860025.253_20220929_0661_a-08_frame761.jpg',
# ...

# %%
e1 = [i.split('\\')[1] for i in e]
e1
# Out:
# ['a01mr1_121_4ea_1690317.547_20221011_0961_a-01_frame472.jpg',
#  'a01mr1_121_4ea_1690317.547_20221011_0961_a-02_frame472.jpg',
#  'a01mr1_121_4ea_1690317.547_20221011_0961_a-03_frame472.jpg',
#  'a01mr1_121_4ea_1690317.547_20221011_0961_a-04_frame472.jpg',
#  'a01mr1_121_4ea_1690317.547_20221011_0961_a-05_frame472.jpg',
#  'a01mr1_121_4ea_1690317.547_20221011_0961_a-06_frame472.jpg',
#  'a01mr1_121_4ea_1690317.547_20221011_0961_a-07_frame472.jpg',
#  'a01mr1_121_4ea_1690317.547_20221011_0961_a-08_frame472.jpg',
#  'a01mr1_125_4ea_1690317.547_20221011_0965_a-01_frame534.jpg',
#  'a01mr1_125_4ea_1690317.547_20221011_0965_a-02_frame534.jpg',
#  'a01mr1_125_4ea_1690317.547_20221011_0965_a-03_frame534.jpg',
#  'a01mr1_125_4ea_1690317.547_20221011_0965_a-04_frame534.jpg',
#  'a01mr1_125_4ea_1690317.547_20221011_0965_a-05_frame534.jpg',
#  'a01mr1_125_4ea_1690317.547_20221011_0965_a-06_frame534.jpg',
#  'a01mr1_125_4ea_1690317.547_20221011_0965_a-07_frame534.jpg',
# ...

# %%
from PIL import Image

## 작업할 이미지 폴더 경로 설정
file_path = 'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_아웃프론트/'

for x in e1:
    img = Image.open(file_path+x)
    img.save('C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_아웃프론트_json/'+x)  ## 저장할 폴더 경로 설정

# %% [markdown]
# 왼발 오른발 구분

# %%
from glob import glob
import shutil

file_path = glob('C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_아웃프론트_json/*')
for data in file_path:
    if data.split('\\')[1][4] == 'r':
        shutil.copyfile(data, 'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_아웃프론트_json/images_folder_아웃프론트_오른발/'+data.split('\\')[-1])
    else:
        shutil.copyfile(data, 'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_아웃프론트_json/images_folder_아웃프론트_왼발/'+data.split('\\')[-1])
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[109], line 9
#       7     shutil.copyfile(data, 'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_아웃프론트_json/images_folder_아웃프론트_오른발/'+data.split('\\')[-1])
#       8 else:
# ----> 9     shutil.copyfile(data, 'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_아웃프론트_json/images_folder_아웃프론트_왼발/'+data.split('\\')[-1])
#
# File c:\Users\bluecom014\miniconda3\envs\sesac\Lib\shutil.py:260, in copyfile(src, dst, follow_symlinks)
#     258     os.symlink(os.readlink(src), dst)
#     259 else:
# --> 260     with open(src, 'rb') as fsrc:
#     261         try:
#     262             with open(dst, 'wb') as fdst:
#     263                 # macOS
#
# PermissionError: [Errno 13] Permission denied: 'C:/Users/bluecom014/Desktop/프로젝트 이미지자료/images_folder_아웃프론트_json\\images_folder_아웃프론트_오른발'
